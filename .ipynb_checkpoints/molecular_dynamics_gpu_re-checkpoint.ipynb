# %% [markdown]
# ```{bash}
# pip install uv
# uv venv
# source .venv/bin/activate
# uv init
# uv add --dev ipykernel
# uv run ipython kernel install --user --env VIRTUAL_ENV $(pwd)/.venv --name=cuda-md
# uv run --with jupyter jupyter lab
# ```

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from tqdm.notebook import tqdm
from mpl_toolkits.mplot3d import Axes3D
import math
import time
import re
from scipy.optimize import minimize
import seaborn as sns

from Constants import *

# %%
try:
  import numba as nb
  from numba import cuda
except Exception as e:
  print(e)
  # %uv pip install "cuda-bindings<13.0" "cuda-core<13.0" numba-cuda
  # %uv pip install nvidia-cuda-nvcc-cu12
  # %uv pip install nvidia-nvjitlink-cu12 nvidia-cuda-runtime-cu12
  import numba as nb
  from numba import cuda
try:
  import cupy as cp
except:
  # %uv pip install cupy-cuda12x

# %% [raw]
# import ipywidgets as widgets
# from IPython.display import display
#
# uploader = widgets.FileUpload(nultiple=True)
# display(uploader)

# %% [raw]
# for filename, file_info in uploader.value.items():
#     with open(filename, "wb") as f:
#         f.write(file_info['content'])

# %% [markdown]
# # Initialize Positions and Velocities

# %%
from Forces import assign_position, initialize_chain_numba, initialize_velocities_cupy, initialize_velocities_cpu

# %% [markdown]
# # Define Forces

# %%
from Forces import harmonic_force, repulsive_lj_force, attractive_lj_force, calc_force, minimum_image_1d

# %% [markdown]
# # Exact Force Computation

# %%
from ExactKernels import calc_force_sequential

# %% [markdown]
# ## Method 0: Segmented Traversal

# %%
from ExactKernels import calc_force_segmented

# %% [markdown]
# ## Method 1: Force Matrix

# %% [markdown]
# Map block (blockIdx = b) to upper triangular tiles (row, col)
# - r = $\lceil N - 0.5 - \frac{\sqrt{(2N+1)^2-8(b+1)}}{2} \rceil $
# - c = $b+r-\frac{(2N-r+1)r}{2}$

# %%
from ExactKernels import calc_force_matrix

# %% [markdown]
# ## Method 2: Explicit Force Matrix

# %% [markdown]
# Map thread (global index = b) to upper triangular tiles (row, col). $n$ is number of atoms here
# - r = $\lceil n - 0.5 - \frac{\sqrt{(2n+1)^2-8(b+1)}}{2} \rceil $
# - c = $b+r-\frac{(2n-r+1)r}{2}$
#
# Map (row, col) to idx:
# - idx = $\frac{(2n-r+1)r}{2} +c-r$

# %%
from ExactKernels import calc_force_matrix_explicit, force_mat_sum

# %% [markdown]
# ## Test and Timing

# %%
from ExactKernels import calc_force_sequential, calc_force_matrix_wrapper, calc_force_segmented_wrapper, calc_force_matrix_explicit_wrapper

# %%
seed = 42
rng_np = np.random.default_rng(seed)
rng_cp = cp.random.default_rng(seed)
chain_lens = np.round(np.linspace(1e3, 1e4, 10)).astype(np.int32)
k = 500
r0 = 1
epsilon_attractive = 0.5
epsilon_repulsive = 1.0
sigma = 1.0

n_itr = 5
time_df = []
for chain_len in chain_lens:
    print(f"--------------- chain_len = {chain_len} ---------------")

    n_atoms = chain_len
    box_size = n_atoms * r0 * 2.5
    const_params_h = np.array([box_size, k, r0, epsilon_attractive, epsilon_repulsive, sigma])
    const_params_d = cp.array(const_params_h)
    pos = initialize_chain_numba(n_atoms, box_size, r0, rng_np, dtype = np.float64)
    v = initialize_velocities_cupy(n_atoms, target_temperature=0.5, mass=1, rng = rng_cp)
    
    positions_d = cp.array(pos)
    velocities_d = v.copy()
    forces_d = cp.zeros_like(pos)
    
    positions_h = pos
    velocities_h = v.get()
    forces_h = np.zeros_like(pos, dtype=np.float64)

    cpu_times = []
    seg_times = []
    em_times = []
    im_times = []
    
    for i in tqdm(range(n_itr)):
        # cpu
        cpu_start = time.perf_counter_ns()
        calc_force_sequential(forces_h, positions_h, const_params_h)
        cpu_end = time.perf_counter_ns()
        cpu_times.append(cpu_end - cpu_start)

        # segmented
        start_event = cuda.event()
        end_event = cuda.event()
        start_event.record()
        calc_force_segmented_wrapper(forces_d, positions_d, const_params_d)
        end_event.record()
        end_event.synchronize()
        execution_time_ms = cuda.event_elapsed_time(start_event, end_event)
        seg_times.append(execution_time_ms * 1e6)
        if i == n_itr - 1:
            print(f"- segmented: all close = {np.allclose(forces_h, forces_d.get())}")
        
        # explicit matrix
        start_event = cuda.event()
        end_event = cuda.event()
        start_event.record()
        calc_force_matrix_explicit_wrapper(forces_d, positions_d, const_params_d)
        end_event.record()
        end_event.synchronize()
        execution_time_ms = cuda.event_elapsed_time(start_event, end_event)
        em_times.append(execution_time_ms * 1e6)
        if i == n_itr - 1:
            print(f"- explicit matrix: all close = {np.allclose(forces_h, forces_d.get())}")

        # implicit matrix
        start_event = cuda.event()
        end_event = cuda.event()
        start_event.record()
        calc_force_matrix_wrapper(forces_d, positions_d, const_params_d)
        end_event.record()
        end_event.synchronize()
        execution_time_ms = cuda.event_elapsed_time(start_event, end_event)
        im_times.append(execution_time_ms * 1e6)
        if i == n_itr - 1:
            print(f"- implicit matrix: all close = {np.allclose(forces_h, forces_d.get())}")
        
    cpu_df = pd.DataFrame({"time": cpu_times[1:], "n_atom": chain_len, "itr": range(1, n_itr), "type": "cpu"})
    seg_df = pd.DataFrame({"time": seg_times[1:], "n_atom": chain_len, "itr": range(1, n_itr), "type": "segmented_traversal"})
    im_df = pd.DataFrame({"time": im_times[1:], "n_atom": chain_len, "itr": range(1, n_itr), "type": "implicit_force_matrix"})
    em_df = pd.DataFrame({"time": em_times[1:], "n_atom": chain_len, "itr": range(1, n_itr), "type": "explicit_force_matrix"})
    time_df.append(pd.concat([cpu_df, seg_df, im_df, em_df]))
    
time_df = pd.concat(time_df)
# Out:
# --------------- chain_len = 1000 ---------------
#   0%|          | 0/5 [00:00<?, ?it/s]
# - segmented: all close = True
# - explicit matrix: all close = True
# - implicit matrix: all close = True
# --------------- chain_len = 2000 ---------------
#   0%|          | 0/5 [00:00<?, ?it/s]
# /home/compute/chenglin.l/cse4059/CUDA_Molecular_Dynamics/.venv/lib/python3.12/site-packages/numba_cuda/numba/cuda/dispatcher.py:739: NumbaPerformanceWarning: Grid size 63 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# - segmented: all close = True
# - explicit matrix: all close = True
# - implicit matrix: all close = True
# --------------- chain_len = 3000 ---------------
#   0%|          | 0/5 [00:00<?, ?it/s]
# ...

# %%
time_df.to_csv("timing/exact_kernels_timing.csv", index = False)

# %%
time_df = pd.read_csv("timing/exact_kernels_timing.csv")

# %%
fig, ax = plt.subplots(figsize = (7, 5))
sns.lineplot(time_df, x = "n_atom", y = "time", hue = "type", ax = ax)
ax.set_ylabel("time (ns)")
ax.minorticks_on()
ax.grid()
ax.grid(which='minor', linestyle=':', linewidth=0.5)
ax.set_title("Force Computation Timing Comparison")
fig.savefig("timing/exact_kernels_timing_comparison.png", dpi=300)

# %%
comp_df = time_df.groupby(by = ["n_atom", "type"])['time'].agg("mean").reset_index()
comp_df = comp_df.pivot(index = "n_atom", columns = "type", values = "time").reset_index()
kernel_cols = ['explicit_force_matrix', 'implicit_force_matrix', 'segmented_traversal']
for col in kernel_cols:
    comp_df[col] = comp_df['cpu'] / comp_df[col]

# %%
fig, ax = plt.subplots(figsize = (7, 5))
for col in kernel_cols:
    sns.lineplot(comp_df, x='n_atom', y=col, ax=ax, label = col)
ax.set_ylabel("Speedup (x)")
ax.minorticks_on()
ax.grid()
ax.grid(which='minor', linestyle=':', linewidth=0.5)
ax.set_title("Speedup Comparison")
fig.savefig("timing/exact_kernels_speedup_comparison.png", dpi=300)

# %% [markdown]
# # Cutoff

# %% [markdown]
# ## Compare: Naive Sequential

# %% [markdown]
# ## Cell-based Sequential

# %%
@nb.njit
def calc_force_cutoff_cell_based_sequential(
    forces, # global forces array (output)
    positions, # global positions array (input)
    cell_size,
    dim,
    cutoff
):
    params = const_params
    n_particles = positions.shape[1]

    labels = np.zeros(n_particles, dtype=np.int32)
    for i in range(n_particles):
        x = positions[0, i]
        y = positions[1, i]
        z = positions[2, i]
        cell_x = int(x // cell_size) % dim
        cell_y = int(y // cell_size) % dim
        cell_z = int(z // cell_size) % dim
        
        labels[i] = cell_x + cell_y * dim + cell_z * dim * dim

    order = np.argsort(labels)
    labels_sorted = labels[order]
    positions_sorted = positions[:, order]
    org_idx = order
    n_total_cells = dim**3

    counts = np.bincount(labels_sorted, minlength=n_total_cells)
    cell_start = np.zeros(n_total_cells + 1, dtype=np.int32)
    cell_start[1:] = np.cumsum(counts)

    for i in range(n_particles):
        i_o = org_idx[i]

        xi = positions_sorted[0, i]
        yi = positions_sorted[1, i]
        zi = positions_sorted[2, i]

        cx = int((xi % params[BOX_SIZE_IDX]) // cell_size)
        cy = int((yi % params[BOX_SIZE_IDX]) // cell_size)
        cz = int((zi % params[BOX_SIZE_IDX]) // cell_size)

        force_x = 0.0
        force_y = 0.0
        force_z = 0.0

        for dz in range(-1, 2):
            nz = (cz + dz + dim) % dim

            for dy in range(-1, 2):
                ny = (cy + dy + dim) % dim

                for dx in range(-1, 2):
                    nx = (cx + dx + dim) % dim

                    nbr = nx + ny * dim + nz * dim * dim

                    start = cell_start[nbr]
                    end = cell_start[nbr + 1]

                    for j in range(start, end):
                        if j == i:
                            continue

                        xj = positions_sorted[0, j]
                        yj = positions_sorted[1, j]
                        zj = positions_sorted[2, j]

                        xij = minimum_image_1d(xi - xj, params[BOX_SIZE_IDX])
                        yij = minimum_image_1d(yi - yj, params[BOX_SIZE_IDX])
                        zij = minimum_image_1d(zi - zj, params[BOX_SIZE_IDX])

                        r2 = xij * xij + yij * yij + zij * zij
                        if r2 < DIV_BY_ZERO_GUARD * DIV_BY_ZERO_GUARD:
                            continue

                        rij = math.sqrt(r2)

                        if rij > cutoff:
                            continue

                        j_o = org_idx[j]
                        sep = abs(j_o - i_o)

                        fmag = calc_force(rij, params, sep)

                        force_x += fmag * xij / rij
                        force_y += fmag * yij / rij
                        force_z += fmag * zij / rij

        forces[0, i_o] = force_x
        forces[1, i_o] = force_y
        forces[2, i_o] = force_z

# %% [markdown]
# ## GPU

# %%
@cuda.jit
def atom_label_kernel(
    labels, # global labels array (output)
    positions, # global positions array (input)
    cell_size: float, # size of each cell
    dim: int # number of cell in each dimension
):
    idx = cuda.grid(1)
    if idx >= positions.shape[1]:
        return
    x = positions[0, idx]
    y = positions[1, idx]
    z = positions[2, idx]
    cell_x = int(x // cell_size) % dim
    cell_y = int(y // cell_size) % dim
    cell_z = int(z // cell_size) % dim
    
    labels[idx] = cell_x + cell_y * dim + cell_z * dim * dim

# %%
@cuda.jit
def calc_force_cutoff_gpu(
    forces,
    cell_start,
    positions,
    org_idx,
    cell_size,
    n_cells,
    cutoff,
):
    params = cuda.const.array_like(const_params)
    i = cuda.grid(1)

    if i >= positions.shape[1]:
        return

    i_o = org_idx[i]

    xi = positions[0, i]
    yi = positions[1, i]
    zi = positions[2, i]

    cx = int((xi % box_size) // cell_size)
    cy = int((yi % box_size) // cell_size)
    cz = int((zi % box_size) // cell_size)

    force_x = 0.0
    force_y = 0.0
    force_z = 0.0

    for dz in range(-1, 2):
        nz = (cz + dz + n_cells) % n_cells

        for dy in range(-1, 2):
            ny = (cy + dy + n_cells) % n_cells

            for dx in range(-1, 2):
                nx = (cx + dx + n_cells) % n_cells

                nbr = nx + ny * n_cells + nz * n_cells * n_cells

                start = cell_start[nbr]
                end = cell_start[nbr + 1]

                for j in range(start, end):
                    if j == i:
                        continue

                    xj = positions[0, j]
                    yj = positions[1, j]
                    zj = positions[2, j]

                    xij = minimum_image_1d(xi - xj, params[BOX_SIZE_IDX])
                    yij = minimum_image_1d(yi - yj, params[BOX_SIZE_IDX])
                    zij = minimum_image_1d(zi - zj, params[BOX_SIZE_IDX])

                    r2 = xij * xij + yij * yij + zij * zij
                    if r2 < DIV_BY_ZERO_GUARD * DIV_BY_ZERO_GUARD:
                        continue

                    rij = math.sqrt(r2)

                    if rij > cutoff:
                        continue

                    j_o = org_idx[j]
                    sep = abs(j_o - i_o)

                    fmag = calc_force(rij, params, sep)

                    force_x += fmag * xij / rij
                    force_y += fmag * yij / rij
                    force_z += fmag * zij / rij

    forces[0, i_o] = force_x
    forces[1, i_o] = force_y
    forces[2, i_o] = force_z

# %% [markdown]
# # Velocity Verlet Integration

# %% [markdown]
# 1. Position update
# $$ r(t+\Delta t) = r(t) + v(t)\Delta t + \frac{F(t)}{2m} \Delta t^2 $$
# 2. Velocity update
# $$ v(t+\Delta t) = v(t) + \frac{F(t) + F(t+\Delta t)}{2m} \Delta t $$

# %% [markdown]
# Naive implementation
# ```{python}
# for step in range(t_steps):
#   forces = compute_forces(positions)  # F(t)
#   v += 0.5 * forces / mass * dt
#   positions += v * dt
#   wrap(positions)
#   forces = compute_forces(positions)  # F(t + dt)
#   v += 0.5 * forces / mass * dt
#   if step % rescale_interval == 0:
#     v = rescale(v)
# ```
#
# Notice that F(t + dt, step i-1) = F(t, step i)<br>
# Pattern: (f 0.5v p f 0.5v rescale) (f 0.5v p f 0.5v) (f 0.5v p f 0.5v)<br>
# Change to: (f 0.5v p) (f 0.5v rescale f 0.5v p) (f 0.5v f 0.5v p) (f 0.5v) <br>
# Need to calculate: (f 0.5v p) (f 0.5v rescale 0.5v p) (f v p) <br>
#
# Optimized sequential version
# ```{python}
# # first iteration
# // launch v_update
# forces = compute_forces(positions)  # F(t)
# v += 0.5 * forces / mass * dt
# positions += v * dt
# for step in range(1, t_steps):
#   // launch v_update
#   forces = compute_forces(positions)  # F(t + dt)
#   dv = forces / mass * dt
#   if (step-1) % rescale_interval == 0:
#     v += 0.5 * dv
#     v = rescale(v)
#     v += 0.5 * dv
#   else:
#     v += dv
#   positions += v * dt
#   wrap(positions)
# ```

# %%
from VelocityVerlet import run_md, write_traj

# %%
def calc_force_cutoff_sequential_wrapper(forces, positions):
    calc_force_cutoff_sequential(forces, positions, const_params[SIGMA_IDX] * CUTOFF_COEFF)
    
def calc_force_cutoff_cell_based_sequential_wrapper(forces, positions):
    dim = CELL_DIM
    cell_size = const_params[BOX_SIZE_IDX] / dim
    cutoff = const_params[SIGMA_IDX] * CUTOFF_COEFF
    calc_force_cutoff_cell_based_sequential(
        forces, # global forces array (output)
        positions, # global positions array (input)
        cell_size,
        dim,
        cutoff
    )

def calc_force_cutoff_gpu_wrapper(forces, positions):
    labels_d = cp.zeros(positions.shape[1], dtype=cp.int32)
    dim = CELL_DIM
    cell_size = const_params[BOX_SIZE_IDX] / dim
    cutoff = const_params[SIGMA_IDX] * CUTOFF_COEFF
    n_total_cells = dim ** 3
    grid_size = (positions.shape[1] + CUTOFF_BLOCK_SIZE - 1) // CUTOFF_BLOCK_SIZE

    # label stage
    atom_label_kernel[grid_size, CUTOFF_BLOCK_SIZE](labels_d, positions, cell_size, dim)

    # sort + build cell_start stage
    order = cp.argsort(labels_d)
    labels_sorted = labels_d[order]
    positions_sorted = positions[:, order]
    orig_idx_sorted = order

    counts = cp.bincount(labels_sorted, minlength=n_total_cells)
    cell_start = cp.zeros(n_total_cells + 1, dtype=cp.int32)
    cell_start[1:] = cp.cumsum(counts)

    # force stage
    cell_start_nb = cuda.as_cuda_array(cell_start)
    positions_sorted_nb = cuda.as_cuda_array(positions_sorted)
    orig_idx_sorted_nb = cuda.as_cuda_array(orig_idx_sorted)
    calc_force_cutoff_gpu[grid_size, CUTOFF_BLOCK_SIZE](
        forces,
        cell_start_nb,
        positions_sorted_nb,
        orig_idx_sorted_nb,
        cell_size,
        dim,
        cutoff
    )

# %%
n_atoms = 1000
k = 500
r0 = 1
box_size = n_atoms * r0 * 2.5
epsilon_attractive = 0.5
epsilon_repulsive = 1.0
sigma = 1.0
const_params = np.array([box_size, k, r0, epsilon_attractive, epsilon_repulsive, sigma])

seed = 42
rng_np = np.random.default_rng(seed)
rng_cp = cp.random.default_rng(seed)

dt = 0.01
mass = 1
temperature = 0.5
steps = 1001
rescale_interval = 100
save_interval = 10

pos = initialize_chain_numba(n_atoms, box_size, r0, rng_np, dtype = np.float64)
# pos = np.load("traj/energy_minimized_layered_1000.npy")
v = initialize_velocities_cupy(n_atoms, target_temperature=temperature, mass=mass, rng = rng_cp)

# %%
box_size
# Out:
# 125.0

# %%
positions_d = cp.array(pos)
velocities_d = v.copy()
forces_d = cp.zeros_like(pos)
frames_cg = run_md(
  positions_d, velocities_d, cp.array(const_params), calc_force_cutoff_gpu_wrapper, dt, mass, temperature,
  steps, box_size,
  rescale_interval,
  save_interval,
  device = True
)
write_traj(f"traj/cutoff_gpu_n_{n_atoms}.xyz", frames_cg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 5
#       1 positions_d = cp.array(pos)
#       2 velocities_d = v.copy()
#       3 forces_d = cp.zeros_like(pos)
#       4 frames_cg = run_md(
# ----> 5   positions_d, velocities_d, cp.array(const_params), calc_force_cutoff_gpu_wrapper, dt, mass, temperature,
#       6   steps, box_size,
#       7   rescale_interval,
#       8   save_interval,
#
# NameError: name 'calc_force_cutoff_gpu_wrapper' is not defined

# %%
positions_h = pos.copy()
velocities_h = v.get()
forces_h = np.zeros_like(pos)
frames_ccs = run_md(
  positions_h, velocities_h, const_params, calc_force_cutoff_sequential_wrapper, dt, mass, temperature,
  steps, box_size,
  rescale_interval,
  save_interval,
  device = False
)
write_traj(f"traj/cutoff_cpu_n_{n_atoms}.xyz", frames_ccs)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
positions_h = pos.copy()
velocities_h = v.get()
forces_h = np.zeros_like(pos)
frames_cc = run_md(
  positions_h, velocities_h, const_params, calc_force_cutoff_cell_based_sequential_wrapper, dt, mass, temperature,
  steps, box_size,
  rescale_interval,
  save_interval,
  device = False
)
write_traj(f"traj/cutoff_cpu_cell_based_n_{n_atoms}.xyz", frames_cc)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
positions_d = cp.array(pos)
velocities_d = v.copy()
forces_d = cp.zeros_like(pos)
frames_fm = run_md(
  positions_d, velocities_d, cp.array(const_params), calc_force_matrix_wrapper, dt, mass, temperature,
  steps, box_size,
  rescale_interval,
  save_interval,
  device = True
)
write_traj(f"traj/force_matrix_n_{n_atoms}.xyz", frames_fm)
# Out:
# /home/compute/chenglin.l/cse4059/CUDA_Molecular_Dynamics/.venv/lib/python3.12/site-packages/numba_cuda/numba/cuda/dispatcher.py:739: NumbaPerformanceWarning: Grid size 3 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
positions_d = cp.array(pos)
velocities_d = v.copy()
forces_d = cp.zeros_like(pos)
frames_fme = run_md(
  positions_d, velocities_d, const_params, calc_force_matrix_explicit_wrapper, dt, mass, temperature,
  steps, box_size,
  rescale_interval,
  save_interval,
  device = True
)
write_traj(f"traj/force_matrix_explicit_n_{n_atoms}.xyz", frames_fme)
# Out:
# /home/compute/chenglin.l/cse4059/CUDA_Molecular_Dynamics/.venv/lib/python3.12/site-packages/numba_cuda/numba/cuda/dispatcher.py:739: NumbaPerformanceWarning: Grid size 50 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
positions_d = cp.array(pos)
velocities_d = v.copy()
frames_st = run_md(
  positions_d, velocities_d, const_params, calc_force_segmented_wrapper, dt, mass, temperature,
  steps, box_size,
  rescale_interval,
  save_interval,
  device = True
)
write_traj(f"traj/segment_n_{n_atoms}.xyz", frames_st)
# Out:
# /home/compute/chenglin.l/cse4059/CUDA_Molecular_Dynamics/.venv/lib/python3.12/site-packages/numba_cuda/numba/cuda/dispatcher.py:739: NumbaPerformanceWarning: Grid size 2 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
positions_h = pos.copy()
velocities_h = v.get()
forces_h = np.zeros_like(pos)
frames_cpu = run_md(
  positions_h, velocities_h, const_params, calc_force_sequential, dt, mass, temperature,
  steps, box_size,
  rescale_interval,
  save_interval,
  device = False
)
write_traj(f"traj/sequential_n_{n_atoms}.xyz", frames_cpu)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# ## Timing

# %%
seed = 42
rng_np = np.random.default_rng(seed)
rng_cp = cp.random.default_rng(seed)
chain_lens = np.round(np.linspace(1e3, 1e4, 5)).astype(np.int32)
k = 500
r0 = 1
epsilon_attractive = 0.5
epsilon_repulsive = 1.0
sigma = 1.0
dt = 0.01
mass = 1
temperature = 0.5
steps = 101
rescale_interval = 100
save_interval = 10

n_itr = 1
time_df = []
for chain_len in chain_lens:
    print(f"--------------- chain_len = {chain_len} ---------------")

    n_atoms = chain_len
    box_size = n_atoms * r0 * 2.5
    const_params_h = np.array([box_size, k, r0, epsilon_attractive, epsilon_repulsive, sigma])
    const_params_d = cp.array(const_params_h)
    pos = initialize_chain_numba(n_atoms, box_size, r0, rng_np, dtype = np.float64)
    v = initialize_velocities_cupy(n_atoms, target_temperature=0.5, mass=1, rng = rng_cp)
    
    cpu_times = []
    seg_times = []
    em_times = []
    im_times = []
    
    for i in range(n_itr):
        # cpu
        positions_h = pos.copy()
        velocities_h = v.get()
        start = time.perf_counter_ns()
        frames = run_md(
          positions_h, velocities_h, const_params_h, calc_force_sequential, dt, mass, temperature,
          steps, box_size,
          rescale_interval,
          save_interval,
          device = False
        )
        end = time.perf_counter_ns()
        cpu_times.append(end - start)

        # segmented
        positions_d = cp.array(pos)
        velocities_d = v.copy()
        start = time.perf_counter_ns()
        frames2 = run_md(
          positions_d, velocities_d, const_params_d, calc_force_segmented_wrapper, dt, mass, temperature,
          steps, box_size,
          rescale_interval,
          save_interval,
          device = True
        )
        end = time.perf_counter_ns()
        seg_times.append(end - start)
        
        # explicit matrix
        positions_d = cp.array(pos)
        velocities_d = v.copy()
        start = time.perf_counter_ns()
        frames2 = run_md(
          positions_d, velocities_d, const_params_d, calc_force_matrix_explicit_wrapper, dt, mass, temperature,
          steps, box_size,
          rescale_interval,
          save_interval,
          device = True
        )
        end = time.perf_counter_ns()
        em_times.append(end - start)
       
        # implicit matrix
        positions_d = cp.array(pos)
        velocities_d = v.copy()
        start = time.perf_counter_ns()
        frames2 = run_md(
          positions_d, velocities_d, const_params_d, calc_force_matrix_wrapper, dt, mass, temperature,
          steps, box_size,
          rescale_interval,
          save_interval,
          device = True
        )
        end = time.perf_counter_ns()
        im_times.append(end - start)
        
    cpu_df = pd.DataFrame({"time": cpu_times, "n_atom": chain_len, "itr": range(n_itr), "type": "cpu"})
    seg_df = pd.DataFrame({"time": seg_times, "n_atom": chain_len, "itr": range(n_itr), "type": "segmented_traversal"})
    im_df = pd.DataFrame({"time": im_times, "n_atom": chain_len, "itr": range(n_itr), "type": "implicit_force_matrix"})
    em_df = pd.DataFrame({"time": em_times, "n_atom": chain_len, "itr": range(n_itr), "type": "explicit_force_matrix"})
    time_df.append(pd.concat([cpu_df, seg_df, im_df, em_df]))
    
time_df = pd.concat(time_df)
# Out:
# --------------- chain_len = 1000 ---------------
# ...
#   0%|          | 0/100 [00:00<?, ?it/s]
# --------------- chain_len = 3250 ---------------
# ...
#   0%|          | 0/100 [00:00<?, ?it/s]
# --------------- chain_len = 5500 ---------------
# ...
#   0%|          | 0/100 [00:00<?, ?it/s]
# --------------- chain_len = 7750 ---------------
# ...
#   0%|          | 0/100 [00:00<?, ?it/s]
# --------------- chain_len = 10000 ---------------
# ...
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
time_df
# Out:
#            time  n_atom  itr                   type
# 0    2666953708    1000    0                    cpu
# 0     259083404    1000    0    segmented_traversal
# 0      65441006    1000    0  implicit_force_matrix
# 0      82903784    1000    0  explicit_force_matrix
# 0   27704756050    3250    0                    cpu
# 0     917150940    3250    0    segmented_traversal
# 0     307607080    3250    0  implicit_force_matrix
# 0     531485409    3250    0  explicit_force_matrix
# 0   79174605670    5500    0                    cpu
# 0    1824216330    5500    0    segmented_traversal
# 0     840301292    5500    0  implicit_force_matrix
# 0    1637522163    5500    0  explicit_force_matrix
# 0  156775622987    7750    0                    cpu
# 0    3727448113    7750    0    segmented_traversal
# 0    1657943950    7750    0  implicit_force_matrix
# 0    3189776500    7750    0  explicit_force_matrix
# 0  260760358966   10000    0                    cpu
# ...

# %%
time_df.to_csv("timing/exact_kernels_integration_timing.csv", index = False)

# %%
time_df = pd.read_csv("timing/exact_kernels_integration_timing.csv")

# %%
fig, ax = plt.subplots(figsize = (7, 5))
sns.lineplot(time_df, x = "n_atom", y = "time", hue = "type", ax = ax)
ax.set_ylabel("time (ns)")
ax.minorticks_on()
ax.grid()
ax.grid(which='minor', linestyle=':', linewidth=0.5)
ax.set_title("101 Steps Integration Timing Comparison")
fig.savefig("timing/exact_kernels_integration_timing_comparison.png", dpi=300)

# %%
comp_df = time_df.groupby(by = ["n_atom", "type"])['time'].agg("mean").reset_index()
comp_df = comp_df.pivot(index = "n_atom", columns = "type", values = "time").reset_index()
kernel_cols = ['explicit_force_matrix', 'implicit_force_matrix', 'segmented_traversal']
for col in kernel_cols:
    comp_df[col] = comp_df['cpu'] / comp_df[col]

# %%
fig, ax = plt.subplots(figsize = (7, 5))
for col in kernel_cols:
    sns.lineplot(comp_df, x='n_atom', y=col, ax=ax, label = col)
ax.set_ylabel("Speedup (x)")
ax.minorticks_on()
ax.grid()
ax.grid(which='minor', linestyle=':', linewidth=0.5)
ax.set_title("101 Steps Integration Speedup Comparison")
fig.savefig("timing/exact_kernels_integration_speedup_comparison.png", dpi=300)
